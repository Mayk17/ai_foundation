# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayk17/ai_foundation/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.3

# %%
mydataset = {
    'cars': ["BMW", "VOLVO", "HYUNDAI", "FERRARI", "BENZ", "KIA"],
    'counts':[3, 5, 9, 6, 7, 2 ] # Added dummy values to match the length of 'cars'
}
df = pd.DataFrame(mydataset)
print(df)
# Out:
#       cars  counts
# 0      BMW       3
# 1    VOLVO       5
# 2  HYUNDAI       9
# 3  FERRARI       6
# 4     BENZ       7
# 5      KIA       2

# %%
df.head() # default 5 rows
# Out:
#       cars  counts
# 0      BMW       3
# 1    VOLVO       5
# 2  HYUNDAI       9
# 3  FERRARI       6
# 4     BENZ       7

# %%
df.tail() # default 5 rows
# Out:
#       cars  counts
# 1    VOLVO       5
# 2  HYUNDAI       9
# 3  FERRARI       6
# 4     BENZ       7
# 5      KIA       2

# %%
df.shape
# Out:
# (6, 2)

# %%
df.columns
# Out:
# Index(['cars', 'counts'], dtype='object')

# %%
df.dtypes
# Out:
# cars      object
# counts     int64
# dtype: object

# %%
print(df)
# Out:
#       cars  counts
# 0      BMW       3
# 1    VOLVO       5
# 2  HYUNDAI       9
# 3  FERRARI       6
# 4     BENZ       7
# 5      KIA       2

# %%
df.describe() # numerical columns only
# Out:
#          counts
# count  6.000000
# mean   5.333333
# std    2.581989
# min    2.000000
# 25%    3.500000
# 50%    5.500000
# 75%    6.750000
# max    9.000000

# %%
df.iloc[:] # indexlardan fydalanib malumotlarni olib keladi
# Out:
#       cars  counts
# 0      BMW       3
# 1    VOLVO       5
# 2  HYUNDAI       9
# 3  FERRARI       6
# 4     BENZ       7
# 5      KIA       2

# %%
df.loc[:, "cars"] # bu birinchi qator ikkinchi label dan colum name dan foydalanib malumot osa bo'ladi
# Out:
# 0        BMW
# 1      VOLVO
# 2    HYUNDAI
# 3    FERRARI
# 4       BENZ
# 5        KIA
# Name: cars, dtype: object

# %%
df[df["cars"] == "KIA"]
# Out:
#   cars  counts
# 5  KIA       2

# %%
df["counts"].mean() # o'rtacha miqdorini
# Out:
# np.float64(5.333333333333333)

# %%
df.sum() # stringlar yig'indisi raqamlar bo'sa raqanlarni chiqazib beradi.
# Out:
# cars      BMWVOLVOHYUNDAIFERRARIBENZKIA
# counts                               32
# dtype: object

# %%
df.min()
# Out:
# cars      BENZ
# counts       2
# dtype: object

# %%
df.median(numeric_only=True)
# Out:
# counts    5.5
# dtype: float64

# %%
df.count() # hamma qatorda malumotlar borligin i tekshiradi
# Out:
# cars      6
# counts    6
# dtype: int64

# %%
df.std(numeric_only=True)
# Out:
# counts    2.581989
# dtype: float64

# %%
from re import NOFLAG
data_with_missing = {
    "cars": ["BMW", "KIA", "VOLVO", None, "HYUNDAI", None],
    "counts": [ 4, 5, 7, None, 3, None]
}
df_missing  = pd.DataFrame(data_with_missing)
print(df_missing)
# Out:
#       cars  counts
# 0      BMW     4.0
# 1      KIA     5.0
# 2    VOLVO     7.0
# 3     None     NaN
# 4  HYUNDAI     3.0
# 5     None     NaN

# %%
df_missing.insull().sum()
# Out:
# cars      2
# counts    2
# dtype: int64

# %%
df_missing.dropna() # missing malumotlarni drop qiladi
# Out:
#       cars  counts
# 0      BMW     4.0
# 1      KIA     5.0
# 2    VOLVO     7.0
# 4  HYUNDAI     3.0

# %%
df_missing.fillna({"cars": "unknown", "counts": 0}) #  xato bor joylarga man hohlagan malumotni qoysam bo'ladi
# Out:
#       cars  counts
# 0      BMW     4.0
# 1      KIA     5.0
# 2    VOLVO     7.0
# 3  unknown     0.0
# 4  HYUNDAI     3.0
# 5  unknown     0.0

# %%
df = pd.read_csv("Titanic-Dataset.csv")
df.head()
# faylni chaqirib o'qish uchun
# df = pd.read_excel("Titanic-Dataset.xlsx")
#df = pd.read_excel("test.xlsx")
#df.tail()
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                          Name     Sex   Age  SibSp  Parch  \
# 886                     Montvila, Rev. Juozas    male  27.0      0      0
# 887              Graham, Miss. Margaret Edith  female  19.0      0      0
# 888  Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1      2
# 889                     Behr, Mr. Karl Howell    male  26.0      0      0
# 890                       Dooley, Mr. Patrick    male  32.0      0      0
#
#          Ticket   Fare Cabin Embarked
# 886      211536  13.00   NaN        S
# 887      112053  30.00   B42        S
# 888  W./C. 6607  23.45   NaN        S
# 889      111369  30.00  C148        C
# 890      370376   7.75   NaN        Q

# %%
df.to_excel("test.xlsx")

# %%
#Series => 10
import pandas as pd
cars = pd.Series(["BMW", "KIA", "HYUNDAI"])
print(cars)
# Out:
# 0        BMW
# 1        KIA
# 2    HYUNDAI
# dtype: object

# %%
cars_series = data_with_missing['cars']
print(cars_series)
# Out:
# ['BMW', 'KIA', 'VOLVO', None, 'HYUNDAI', None]
